# %% [markdown]
# # Chapter 3 – Things to Do (Sections 3.1–3.6)
# **Student Name:** Joseph Daniels
# **Purpose:** This notebook answers the end-of-chapter exercises by performing calculations in Python and explaining the results using Markdown.

# %% [markdown]
# ## 3.1 How many seconds are in an hour?

# %%
60 * 60

# %% [markdown]
# ## 3.2 Assign the result from the previous task to a variable called `seconds_per_hour`.

# %%
seconds_per_hour = 60 * 60
seconds_per_hour

# %% [markdown]
# ## 3.3 How many seconds are in a day?

# %%
seconds_per_hour * 24

# %% [markdown]
# ## 3.4 Save the result in a variable called `seconds_per_day`.

# %%
seconds_per_day = seconds_per_hour * 24
seconds_per_day

# %% [markdown]
# ## 3.5 Divide `seconds_per_day` by `seconds_per_hour`.

# %%
seconds_per_day / seconds_per_hour

# %% [markdown]
# ## 3.6 Divide using integer (`//`) division. Did this agree with the floating-point value?
# Yes. Integer division returns `24` while floating-point division returns `24.0`, which represent the same value.

# %%
seconds_per_day // seconds_per_hour
