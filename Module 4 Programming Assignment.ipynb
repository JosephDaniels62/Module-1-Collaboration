# %%
# %%writefile zoo.py

def hours():
    print("Open 9-5 daily")
# Out:
# Overwriting zoo.py

# %%
import zoo
zoo.hours()
# Out:
# Open 9-5 daily

# %%
import zoo as menagerie
menagerie.hours()
# Out:
# Open 9-5 daily

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\blelu\anaconda3\lib\site-packages (2.0.39)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\blelu\anaconda3\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\blelu\anaconda3\lib\site-packages (from sqlalchemy) (4.12.2)

# %%
from sqlalchemy import create_engine, text

engine = create_engine("sqlite:///books.db")

with engine.connect() as conn:
    result = conn.execute(text("SELECT name FROM sqlite_master WHERE type='table';"))
    for row in result:
        print(row[0])

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\blelu\Documents
# ['.ipynb_checkpoints', 'books.db', 'My Music', 'My Pictures', 'My Videos', 'Untitled.ipynb', 'zoo.py', '__pycache__']

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT title FROM book ORDER BY title"))
    for row in result:
        print(row[0])
# Out:
# Catch-22
# Emma
# The Hobbit
